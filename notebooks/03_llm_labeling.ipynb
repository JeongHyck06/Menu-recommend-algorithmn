# %% [markdown]
# # 03. LLM 속성 라벨링
#
# 음식별 속성(매운맛, 국물 여부, 온도, 기름짐 등)을 LLM으로 라벨링하는 방법을 실험한다.
#
# - 라벨링할 속성 정의 및 값 범위 설계
# - 라벨링 프롬프트 설계 및 출력 형식 정의
# - 소규모 샘플로 라벨링 품질 검토
# - LLM SDK 및 모델 선택은 아직 미정
#
# 입력: `data/processed/` / 출력: `data/processed/` (속성 컬럼 추가)

# %% [markdown]
# ## 기본 설정

# %%
import sys
from pathlib import Path

import numpy as np
import pandas as pd

PROJECT_ROOT = Path.cwd().parent
DATA_DIR = PROJECT_ROOT / "data"
sys.path.append(str(PROJECT_ROOT))
